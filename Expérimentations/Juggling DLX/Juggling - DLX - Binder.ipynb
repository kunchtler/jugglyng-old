# %%
import warnings
import os
import time
warnings.filterwarnings('ignore')
os.chdir("../../")
from juggling_dlx_milp import *
display(display_interface())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 6
#       4 warnings.filterwarnings('ignore')
#       5 os.chdir("../../")
# ----> 6 from juggling_dlx_milp import *
#       7 display(display_interface())
#
# File ~/stage/jugglyng-old/Expérimentations/Juggling DLX/juggling_dlx_milp.py:4
#       2 from typing import List, Dict, Tuple, Union, Set, Any, Optional
#       3 from sage.all import MixedIntegerLinearProgram
# ----> 4 from DLX.dlxm import DLXM
#       5 from queue import Queue
#       7 import cppyy
#
# File ~/stage/jugglyng-old/Expérimentations/Juggling DLX/DLX/dlxm.py:10
#       7 _cur_path = os.getcwd()
#       8 os.chdir(_dir_path)
# ---> 10 cppyy.include('dlx_m.hpp')
#      11 cppyy.load_library('dlx_m.so')
#      13 os.chdir(_cur_path)
#
# File ~/mambaforge/envs/juggling2/lib/python3.10/site-packages/cppyy/__init__.py:273, in include(header)
# ...
